# %%
from tqdm import tqdm
import os
import pandas as pd
import numpy as np
from sklearn.svm import OneClassSVM
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px
from sklearn.preprocessing import RobustScaler
from collections import Counter
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (10,10)


from sklearn.decomposition import PCA

from he_svm import preprocess_a_sample, he_svm, preprocess_a_sample_encrypted
import glob

# %%
healthy_csvs = ['data/TriaxalBearings/Healthy bearing data/Healthy with pulley.csv']
                # '../data/TriaxalBearings/Healthy bearing data/healthy without pulley.csv']

LEN_SAMPLES = 500

train_samples = []
for f in healthy_csvs:
    df = pd.read_csv(f)
    df = df.iloc[:, 1:]
    dfs = df.groupby(np.arange(len(df))//LEN_SAMPLES)
    [train_samples.append(t[1]) for t in list(dfs)[:-1]]

# %%
len(train_samples)
# Out:
# 237

# %%
len(train_samples[0])
# Out:
# 500

# %% [markdown]
# # Train a SVM

# %%
def preprocess_a_sample(df, windows):
    final_sample = []
    
    for column in df.columns:
        signal = df.loc[:, column]
        
        signal_fft = np.abs(np.fft.rfft(signal))**2
        len_windows = int(len(signal_fft) / windows) - 1
        
        for i in range(windows):
            if i == windows-1:
                final_sample.append(np.mean(signal_fft[i*len_windows:]))
            else:
                final_sample.append(np.mean(signal_fft[i*len_windows:(i+1)*len_windows]))
                
    return np.array(final_sample)

# %%
windows = 8

# %%
preprocessed_samples_nominal = np.array([preprocess_a_sample(sample, windows) for sample in train_samples])
np.random.seed(42)
np.random.shuffle(preprocessed_samples_nominal)

n = int(len(preprocessed_samples_nominal) * 0.8)
preprocessed_samples_train = preprocessed_samples_nominal[:n]
preprocessed_samples_test = preprocessed_samples_nominal[n:]

svm = OneClassSVM(nu=0.05, kernel='poly', gamma='scale', degree=2)
svm.fit(preprocessed_samples_train)
svm.gamma_value = 1 / ((windows*3) * preprocessed_samples_train.var())  # to put gamma value in svm

# %% [markdown]
# # Test
# ## Test on nominal data

# %%
x_predicted = svm.predict(preprocessed_samples_train)
print(f"###############")
print(f"Training samples: {len(x_predicted)}")
print(f"Found nominal: {len([x for x in x_predicted if x == 1])}")
print(f"Found anomalous: {len([x for x in x_predicted if x == -1])}")
print(f"Accuracy nominal training: {len([x for x in x_predicted if x == 1]) / len(x_predicted)}")

x_predicted = svm.predict(preprocessed_samples_test)
print(f"Test samples (nominal): {len(x_predicted)}")
print(f"Found nominal: {len([x for x in x_predicted if x == 1])}")
print(f"Found anomalous: {len([x for x in x_predicted if x == -1])}")
print(f"Accuracy nominal testing: {len([x for x in x_predicted if x == 1]) / len(x_predicted)}")
# Out:
# ###############
# Training samples: 189
# Found nominal: 179
# Found anomalous: 10
# Accuracy nominal training: 0.9470899470899471
# Test samples (nominal): 48
# Found nominal: 45
# Found anomalous: 3
# Accuracy nominal testing: 0.9375

# %%
print(f'Max distance: {max(svm.decision_function(preprocessed_samples_train))}')
print(f'Min distance: {min(svm.decision_function(preprocessed_samples_train))}')
# Out:
# Max distance: 1.0878100689276433
# Min distance: -0.8507441308006687

# %% [markdown]
# # Test on anomalous data

# %%
# Define the directory
dir = 'data/TriaxalBearings/'

# Get the list of files in the directory and its subdirectories
files = []
for f in glob.glob(dir + '**/*.csv', recursive=True):
    if 'Healthy' not in f:
        files.append(f)

# %%
sides = ['inner', 'outer']
powers = ['100w', '200w', '300w']

multi_index = pd.MultiIndex.from_product([sides, powers], names=['Sides', 'Powers'])
table_accuracy = pd.DataFrame(columns = multi_index) 

for f in sorted(files):
    print(f"File: {f}")
    short_file = f.split("/")[-1][:-4]
    print(short_file)
    
    side = short_file[3:8]
    power = short_file[9:13]
    depth = short_file[:3]
        
    df = pd.read_csv(f)
    df = df.iloc[:, 1:]
    dfs = df.groupby(np.arange(len(df))//LEN_SAMPLES)
    anomalous_samples = [t[1] for t in list(dfs)[:-1]]
    anomaly_samples = np.array([preprocess_a_sample(df, windows) for df in anomalous_samples])

    x_predicted = svm.predict(anomaly_samples)
    
    n_nom = len([x for x in x_predicted if x == 1])
    n_ano = len([x for x in x_predicted if x == -1])
    accuracy = round((n_ano / len(x_predicted)) * 100, 2)
    table_accuracy.loc[depth, (side, power)] = accuracy
    
    print(f"Test samples (anomalous): {len(x_predicted)}")
    print(f"Found nominal: {n_nom}")
    print(f"Found anomalous: {n_ano}")
    print(f"Accuracy: {accuracy}%")
    print(f"###############")

display(table_accuracy)
# Out:
# File: data/TriaxalBearings/0.7mm-bearing-faults/0.7inner-100watt-67V2Iv.csv
# 0.7inner-100watt-67V2Iv
# Test samples (anomalous): 286
# Found nominal: 285
# Found anomalous: 1
# Accuracy: 0.35%
# ###############
# File: data/TriaxalBearings/0.7mm-bearing-faults/0.7inner-200watt-jolm8U.csv
# 0.7inner-200watt-jolm8U
# Test samples (anomalous): 250
# Found nominal: 248
# Found anomalous: 2
# Accuracy: 0.8%
# ###############
# File: data/TriaxalBearings/0.7mm-bearing-faults/0.7inner-300watt-Zo8w7U.csv
# 0.7inner-300watt-Zo8w7U
# Test samples (anomalous): 227
# Found nominal: 227
# Found anomalous: 0
# Accuracy: 0.0%
# ###############
# File: data/TriaxalBearings/0.7mm-bearing-faults/0.7outer-100watt-lB5LIS.csv
# 0.7outer-100watt-lB5LIS
# Test samples (anomalous): 260
# Found nominal: 15
# Found anomalous: 245
# Accuracy: 94.23%
# ###############
# File: data/TriaxalBearings/0.7mm-bearing-faults/0.7outer-200watt-0Pp0qm.csv
# 0.7outer-200watt-0Pp0qm
# Test samples (anomalous): 260
# Found nominal: 127
# Found anomalous: 133
# Accuracy: 51.15%
# ###############
# File: data/TriaxalBearings/0.7mm-bearing-faults/0.7outer-300watt-PzsIeS.csv
# 0.7outer-300watt-PzsIeS
# Test samples (anomalous): 132
# Found nominal: 48
# Found anomalous: 84
# Accuracy: 63.64%
# ###############
# File: data/TriaxalBearings/0.9mm-bearing-faults/0.9inner-100watt.csv
# 0.9inner-100watt
# Test samples (anomalous): 304
# Found nominal: 0
# Found anomalous: 304
# Accuracy: 100.0%
# ###############
# File: data/TriaxalBearings/0.9mm-bearing-faults/0.9inner-200watt.csv
# 0.9inner-200watt
# Test samples (anomalous): 274
# Found nominal: 0
# Found anomalous: 274
# Accuracy: 100.0%
# ###############
# File: data/TriaxalBearings/0.9mm-bearing-faults/0.9inner-300watt.csv
# 0.9inner-300watt
# Test samples (anomalous): 264
# Found nominal: 0
# Found anomalous: 264
# Accuracy: 100.0%
# ###############
# File: data/TriaxalBearings/0.9mm-bearing-faults/0.9outer-100watt.csv
# 0.9outer-100watt
# Test samples (anomalous): 281
# Found nominal: 0
# Found anomalous: 281
# Accuracy: 100.0%
# ###############
# File: data/TriaxalBearings/0.9mm-bearing-faults/0.9outer-200watt.csv
# 0.9outer-200watt
# Test samples (anomalous): 281
# Found nominal: 0
# Found anomalous: 281
# Accuracy: 100.0%
# ###############
# File: data/TriaxalBearings/0.9mm-bearing-faults/0.9outer-300watt.csv
# 0.9outer-300watt
# Test samples (anomalous): 245
# Found nominal: 0
# Found anomalous: 245
# Accuracy: 100.0%
# ###############
# File: data/TriaxalBearings/1.1mm-bearing-faults/1.1inner-100watt.csv
# 1.1inner-100watt
# Test samples (anomalous): 272
# Found nominal: 0
# Found anomalous: 272
# Accuracy: 100.0%
# ###############
# File: data/TriaxalBearings/1.1mm-bearing-faults/1.1inner-200watt.csv
# 1.1inner-200watt
# Test samples (anomalous): 274
# Found nominal: 0
# Found anomalous: 274
# Accuracy: 100.0%
# ###############
# File: data/TriaxalBearings/1.1mm-bearing-faults/1.1inner-300watt.csv
# 1.1inner-300watt
# Test samples (anomalous): 294
# Found nominal: 0
# Found anomalous: 294
# Accuracy: 100.0%
# ###############
# File: data/TriaxalBearings/1.1mm-bearing-faults/1.1outer-100watt.csv
# 1.1outer-100watt
# Test samples (anomalous): 271
# Found nominal: 0
# Found anomalous: 271
# Accuracy: 100.0%
# ###############
# File: data/TriaxalBearings/1.1mm-bearing-faults/1.1outer-200watt.csv
# 1.1outer-200watt
# Test samples (anomalous): 303
# Found nominal: 2
# Found anomalous: 301
# Accuracy: 99.34%
# ###############
# File: data/TriaxalBearings/1.1mm-bearing-faults/1.1outer-300watt.csv
# 1.1outer-300watt
# Test samples (anomalous): 278
# Found nominal: 0
# Found anomalous: 278
# Accuracy: 100.0%
# ###############
# File: data/TriaxalBearings/1.3mm-bearing-faults/1.3inner-100watt.csv
# 1.3inner-100watt
# Test samples (anomalous): 286
# Found nominal: 0
# Found anomalous: 286
# Accuracy: 100.0%
# ###############
# File: data/TriaxalBearings/1.3mm-bearing-faults/1.3inner-200watt.csv
# 1.3inner-200watt
# Test samples (anomalous): 266
# Found nominal: 0
# Found anomalous: 266
# Accuracy: 100.0%
# ###############
# File: data/TriaxalBearings/1.3mm-bearing-faults/1.3inner-300watt.csv
# 1.3inner-300watt
# Test samples (anomalous): 255
# Found nominal: 0
# Found anomalous: 255
# Accuracy: 100.0%
# ###############
# File: data/TriaxalBearings/1.3mm-bearing-faults/1.3outer-100watt.csv
# 1.3outer-100watt
# Test samples (anomalous): 265
# Found nominal: 0
# Found anomalous: 265
# Accuracy: 100.0%
# ###############
# File: data/TriaxalBearings/1.3mm-bearing-faults/1.3outer-200watt.csv
# 1.3outer-200watt
# Test samples (anomalous): 278
# Found nominal: 0
# Found anomalous: 278
# Accuracy: 100.0%
# ###############
# File: data/TriaxalBearings/1.3mm-bearing-faults/1.3outer-300watt.csv
# 1.3outer-300watt
# Test samples (anomalous): 255
# Found nominal: 9
# Found anomalous: 246
# Accuracy: 96.47%
# ###############
# File: data/TriaxalBearings/1.5mm-bearing-faults/1.5inner-100watt.csv
# 1.5inner-100watt
# Test samples (anomalous): 262
# Found nominal: 0
# Found anomalous: 262
# Accuracy: 100.0%
# ###############
# File: data/TriaxalBearings/1.5mm-bearing-faults/1.5inner-200watt.csv
# 1.5inner-200watt
# Test samples (anomalous): 291
# Found nominal: 0
# Found anomalous: 291
# Accuracy: 100.0%
# ###############
# File: data/TriaxalBearings/1.5mm-bearing-faults/1.5inner-300watt.csv
# 1.5inner-300watt
# Test samples (anomalous): 267
# Found nominal: 0
# Found anomalous: 267
# Accuracy: 100.0%
# ###############
# File: data/TriaxalBearings/1.5mm-bearing-faults/1.5outer-100watt.csv
# 1.5outer-100watt
# Test samples (anomalous): 263
# Found nominal: 1
# Found anomalous: 262
# Accuracy: 99.62%
# ###############
# File: data/TriaxalBearings/1.5mm-bearing-faults/1.5outer-200watt.csv
# 1.5outer-200watt
# Test samples (anomalous): 251
# Found nominal: 0
# Found anomalous: 251
# Accuracy: 100.0%
# ###############
# File: data/TriaxalBearings/1.5mm-bearing-faults/1.5outer-300watt.csv
# 1.5outer-300watt
# Test samples (anomalous): 270
# Found nominal: 0
# Found anomalous: 270
# Accuracy: 100.0%
# ###############
# File: data/TriaxalBearings/1.7mm-bearing-faults/1.7inner-100watt.csv
# 1.7inner-100watt
# Test samples (anomalous): 276
# Found nominal: 0
# Found anomalous: 276
# Accuracy: 100.0%
# ###############
# File: data/TriaxalBearings/1.7mm-bearing-faults/1.7inner-200watt.csv
# 1.7inner-200watt
# Test samples (anomalous): 275
# Found nominal: 0
# Found anomalous: 275
# Accuracy: 100.0%
# ###############
# File: data/TriaxalBearings/1.7mm-bearing-faults/1.7inner-300watt.csv
# 1.7inner-300watt
# Test samples (anomalous): 257
# Found nominal: 0
# Found anomalous: 257
# Accuracy: 100.0%
# ###############
# File: data/TriaxalBearings/1.7mm-bearing-faults/1.7outer-100watt.csv
# 1.7outer-100watt
# Test samples (anomalous): 272
# Found nominal: 0
# Found anomalous: 272
# Accuracy: 100.0%
# ###############
# File: data/TriaxalBearings/1.7mm-bearing-faults/1.7outer-200watt.csv
# 1.7outer-200watt
# Test samples (anomalous): 261
# Found nominal: 0
# Found anomalous: 261
# Accuracy: 100.0%
# ###############
# File: data/TriaxalBearings/1.7mm-bearing-faults/1.7outer-300watt.csv
# 1.7outer-300watt
# Test samples (anomalous): 274
# Found nominal: 0
# Found anomalous: 274
# Accuracy: 100.0%
# ###############
# Sides   inner                outer
# Powers   100w   200w   300w   100w   200w   300w
# 0.7      0.35    0.8    0.0  94.23  51.15  63.64
# 0.9     100.0  100.0  100.0  100.0  100.0  100.0
# 1.1     100.0  100.0  100.0  100.0  99.34  100.0
# 1.3     100.0  100.0  100.0  100.0  100.0  96.47
# 1.5     100.0  100.0  100.0  99.62  100.0  100.0
# 1.7     100.0  100.0  100.0  100.0  100.0  100.0

# %% [markdown]
# # Test on encrypted data

# %%
from linetimer import CodeTimer
import tenseal as ts
np.set_printoptions(precision=3, suppress=True)

poly_modulus_degree=2**14
coeff_mod_bit_sizes=[60] + [50]*6 + [60]

# Setup TenSEAL context
context = ts.context(
            ts.SCHEME_TYPE.CKKS,
            poly_modulus_degree=poly_modulus_degree,
            coeff_mod_bit_sizes=coeff_mod_bit_sizes
          )
context.generate_galois_keys()
context.global_scale = 2**50

errors = {}

for f in files:
    error_df = pd.DataFrame(columns=['ID', 'Expected', 'Predicted (enc)', '% Error', 'Correct?', 'Time enc (s)'])
    df = pd.read_csv(f)
    df = df.iloc[:, 1:]
    dfs = df.groupby(np.arange(len(df))//LEN_SAMPLES)
    anomalous_samples = [t[1] for t in list(dfs)[:-1]]
    
    for sample in anomalous_samples[:]:
        anomaly_sample = preprocess_a_sample(sample, windows).reshape(1, -1)
        
        x_expected = svm.decision_function(anomaly_sample)[0]

        enc_time = CodeTimer(silent=True, unit='s')
        with enc_time:
            x_enc_preprocessed = preprocess_a_sample_encrypted(sample, context, windows, None)
            x_enc_predicted = he_svm(x_enc_preprocessed, svm, windows)
            x_predicted = x_enc_predicted[0].decrypt()[0]

        error_df.loc[len(error_df)] = [sample.index.name, x_expected, x_predicted, 
                                       (x_expected-x_predicted)/x_expected, 
                                       np.sign(x_expected) == np.sign(x_predicted),
                                       enc_time.took]

    f = f.split("/")[-1][:-4]
    errors[f] = error_df
    error_df.to_csv(f"results/Errors_{f}.csv")

    print(f"Sensor: {f}")
    print(error_df)
# Out:
# Sensor: 1.7outer-200watt
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -1.814035        -1.814035  1.236486e-07      True      8.622367
# 1    None -1.023244        -1.023244  2.420663e-07      True      8.233833
# 2    None -1.439210        -1.439210  1.635290e-07      True      8.119912
# 3    None -1.617385        -1.617385  1.422819e-07      True      8.506666
# 4    None -1.391745        -1.391745  1.699395e-07      True      8.027988
# ..    ...       ...              ...           ...       ...           ...
# 256  None -1.138934        -1.138934  2.146137e-07      True      7.636614
# 257  None -1.562010        -1.562009  1.483974e-07      True      7.940823
# 258  None -1.258263        -1.258262  1.913164e-07      True      7.930412
# 259  None -1.881938        -1.881938  1.182275e-07      True      7.806514
# 260  None -1.756475        -1.756475  1.288703e-07      True      7.877173
#
# [261 rows x 6 columns]
# Sensor: 1.7outer-100watt
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -1.824547        -1.824547  1.228496e-07      True      7.708710
# 1    None -1.052470        -1.052470  2.340420e-07      True      7.935950
# 2    None -1.858088        -1.858088  1.199234e-07      True      7.781801
# 3    None -1.128959        -1.128959  2.159512e-07      True      7.494411
# 4    None -1.325850        -1.325850  1.799300e-07      True      7.926152
# ..    ...       ...              ...           ...       ...           ...
# 267  None -1.795413        -1.795413  1.252904e-07      True      7.786995
# 268  None -1.194685        -1.194685  2.029092e-07      True      7.676972
# 269  None -2.137846        -2.137846  1.004789e-07      True      7.954728
# 270  None -2.087551        -2.087551  1.036933e-07      True      7.669297
# 271  None -1.851132        -1.851132  1.205311e-07      True      7.441745
#
# [272 rows x 6 columns]
# Sensor: 1.7inner-300watt
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -1.461933        -1.461933  1.602098e-07      True      7.525771
# 1    None -1.027689        -1.027689  2.402654e-07      True      7.728227
# 2    None -1.221375        -1.221375  1.974724e-07      True      7.945507
# 3    None -1.645901        -1.645901  1.390625e-07      True      7.525538
# 4    None -1.211395        -1.211395  1.995051e-07      True      7.830974
# ..    ...       ...              ...           ...       ...           ...
# 252  None -1.441182        -1.441181  1.630192e-07      True      8.013881
# 253  None -1.138395        -1.138395  2.142426e-07      True      8.117988
# 254  None -1.432780        -1.432780  1.641822e-07      True      7.692908
# 255  None -0.864981        -0.864980  2.907773e-07      True      8.071290
# 256  None -1.416974        -1.416974  1.661607e-07      True      7.932618
#
# [257 rows x 6 columns]
# Sensor: 1.7inner-200watt
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -3.177106        -3.177106  5.827658e-08      True      8.077968
# 1    None -1.013821        -1.013821  2.440086e-07      True      7.904596
# 2    None -1.555440        -1.555440  1.491110e-07      True      7.866371
# 3    None -1.001497        -1.001496  2.466148e-07      True      8.045606
# 4    None -0.595506        -0.595506  4.365648e-07      True      8.127324
# ..    ...       ...              ...           ...       ...           ...
# 270  None -0.279655        -0.279655  9.605683e-07      True      8.075399
# 271  None -0.629954        -0.629954  4.095919e-07      True      8.164707
# 272  None -1.304108        -1.304108  1.831829e-07      True      8.058265
# 273  None -1.609760        -1.609760  1.430153e-07      True      8.175326
# 274  None -0.765873        -0.765873  3.325486e-07      True      8.201696
#
# [275 rows x 6 columns]
# Sensor: 1.7inner-100watt
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -1.244168        -1.244168  1.931946e-07      True      8.267020
# 1    None -0.907748        -0.907748  2.759404e-07      True      8.199447
# 2    None -1.084176        -1.084175  2.260821e-07      True      8.119221
# 3    None -1.172597        -1.172597  2.069159e-07      True      8.149434
# 4    None -0.836096        -0.836096  3.015946e-07      True      8.183022
# ..    ...       ...              ...           ...       ...           ...
# 271  None -1.216341        -1.216341  1.991080e-07      True      7.144429
# 272  None -0.714687        -0.714687  3.583042e-07      True      7.383826
# 273  None -1.154770        -1.154770  2.101399e-07      True      7.055717
# 274  None -1.140870        -1.140870  2.134302e-07      True      7.741699
# 275  None -0.979331        -0.979331  2.543406e-07      True      7.334632
#
# [276 rows x 6 columns]
# Sensor: 1.7outer-300watt
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -0.473495        -0.473494  5.563577e-07      True      7.351758
# 1    None -1.581897        -1.581896  1.463367e-07      True      7.207208
# 2    None -1.762902        -1.762902  1.279125e-07      True      7.095556
# 3    None -1.445879        -1.445879  1.623750e-07      True      7.051023
# 4    None -1.411677        -1.411677  1.673263e-07      True      7.116910
# ..    ...       ...              ...           ...       ...           ...
# 269  None -1.386878        -1.386878  1.709880e-07      True      7.969061
# 270  None -1.893265        -1.893265  1.170900e-07      True      7.923405
# 271  None -1.363980        -1.363980  1.739377e-07      True      8.137869
# 272  None -1.623718        -1.623718  1.415627e-07      True      7.705641
# 273  None -1.672619        -1.672619  1.368887e-07      True      7.774159
#
# [274 rows x 6 columns]
# Sensor: 1.5outer-100watt
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -1.141262        -1.141262  2.138920e-07      True      7.667721
# 1    None -1.586836        -1.586836  1.456649e-07      True      7.657494
# 2    None -0.510557        -0.510557  5.133439e-07      True      7.582949
# 3    None -1.413076        -1.413076  1.668509e-07      True      7.675087
# 4    None -1.500591        -1.500590  1.551938e-07      True      7.799860
# ..    ...       ...              ...           ...       ...           ...
# 258  None -1.014411        -1.014411  2.437803e-07      True      7.554829
# 259  None -0.717550        -0.717549  3.557662e-07      True      7.685530
# 260  None -0.663929        -0.663929  3.876416e-07      True      7.987701
# 261  None -0.481925        -0.481924  5.451295e-07      True      8.039645
# 262  None -0.793532        -0.793532  3.196186e-07      True      8.226767
#
# [263 rows x 6 columns]
# Sensor: 1.5inner-100watt
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -1.352812        -1.352811  1.759624e-07      True      8.545563
# 1    None -0.631850        -0.631850  4.098012e-07      True      8.158089
# 2    None -1.367625        -1.367625  1.734270e-07      True      7.999523
# 3    None -1.005340        -1.005340  2.466129e-07      True      7.679017
# 4    None -1.490011        -1.490010  1.567198e-07      True      8.078180
# ..    ...       ...              ...           ...       ...           ...
# 257  None -1.310891        -1.310891  1.823189e-07      True      7.917952
# 258  None -1.571482        -1.571482  1.474879e-07      True      8.079435
# 259  None -1.985910        -1.985909  1.104098e-07      True      8.116747
# 260  None -1.460842        -1.460841  1.605280e-07      True      8.089389
# 261  None -1.964431        -1.964431  1.119042e-07      True      8.143924
#
# [262 rows x 6 columns]
# Sensor: 1.5inner-300watt
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -2.033789        -2.033788  1.074394e-07      True      8.104453
# 1    None -2.678590        -2.678590  7.428034e-08      True      8.018467
# 2    None -1.971715        -1.971715  1.113314e-07      True      8.141560
# 3    None -1.752049        -1.752049  1.290973e-07      True      7.802222
# 4    None -2.158440        -2.158439  9.903613e-08      True      8.003715
# ..    ...       ...              ...           ...       ...           ...
# 262  None -1.891575        -1.891574  1.171610e-07      True      8.264478
# 263  None -1.490698        -1.490698  1.566606e-07      True      8.242271
# 264  None -1.674047        -1.674047  1.364307e-07      True      8.217468
# 265  None -1.771154        -1.771154  1.273656e-07      True      8.336148
# 266  None -1.667957        -1.667956  1.370224e-07      True      7.946545
#
# [267 rows x 6 columns]
# Sensor: 1.5outer-200watt
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -0.517877        -0.517877  5.051057e-07      True      7.961667
# 1    None -1.148144        -1.148144  2.124979e-07      True      7.850829
# 2    None -1.127476        -1.127476  2.160479e-07      True      8.261422
# 3    None -1.145533        -1.145533  2.126035e-07      True      8.214046
# 4    None -1.030196        -1.030196  2.398803e-07      True      8.308745
# ..    ...       ...              ...           ...       ...           ...
# 246  None -1.194801        -1.194800  2.026027e-07      True      8.230887
# 247  None -1.208654        -1.208654  2.000584e-07      True      8.288762
# 248  None -0.670356        -0.670356  3.834499e-07      True      8.187387
# 249  None -0.930331        -0.930330  2.684052e-07      True      7.990930
# 250  None -0.772914        -0.772913  3.293395e-07      True      7.848002
#
# [251 rows x 6 columns]
# Sensor: 1.5outer-300watt
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -1.345176        -1.345176  1.766853e-07      True      8.223853
# 1    None -1.443405        -1.443405  1.628924e-07      True      8.415285
# 2    None -1.256037        -1.256037  1.912902e-07      True      8.028985
# 3    None -0.878558        -0.878558  2.870725e-07      True      8.269342
# 4    None -1.374703        -1.374703  1.725739e-07      True      7.874143
# ..    ...       ...              ...           ...       ...           ...
# 265  None -1.023088        -1.023088  2.417065e-07      True      7.772237
# 266  None -1.387202        -1.387201  1.706394e-07      True      7.709483
# 267  None -1.016442        -1.016442  2.436338e-07      True      7.707951
# 268  None -1.330509        -1.330509  1.792773e-07      True      7.889962
# 269  None -1.287891        -1.287891  1.855957e-07      True      7.820361
#
# [270 rows x 6 columns]
# Sensor: 1.5inner-200watt
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -1.351519        -1.351518  1.757855e-07      True      7.623850
# 1    None -1.474338        -1.474337  1.589393e-07      True      7.638555
# 2    None -1.716288        -1.716288  1.321985e-07      True      7.886520
# 3    None -1.676662        -1.676662  1.362587e-07      True      7.795702
# 4    None -1.695454        -1.695454  1.343912e-07      True      8.087381
# ..    ...       ...              ...           ...       ...           ...
# 286  None -1.456619        -1.456619  1.611699e-07      True      8.228734
# 287  None -1.982139        -1.982138  1.108726e-07      True      8.268510
# 288  None -1.392314        -1.392314  1.699354e-07      True      8.196172
# 289  None -1.703583        -1.703583  1.336306e-07      True      8.218361
# 290  None -1.622591        -1.622591  1.413984e-07      True      8.364334
#
# [291 rows x 6 columns]
# Sensor: 1.1outer-300watt
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -1.504491        -1.504491  1.550579e-07      True      7.935794
# 1    None -1.096254        -1.096254  2.233735e-07      True      8.089548
# 2    None -1.170667        -1.170667  2.076471e-07      True      8.080656
# 3    None -1.219304        -1.219303  1.977027e-07      True      8.204592
# 4    None -1.610861        -1.610861  1.429490e-07      True      8.107956
# ..    ...       ...              ...           ...       ...           ...
# 273  None -1.410553        -1.410552  1.674593e-07      True      8.085764
# 274  None -1.253688        -1.253688  1.920550e-07      True      8.140843
# 275  None -1.336935        -1.336935  1.779837e-07      True      8.186238
# 276  None -2.116949        -2.116949  1.017128e-07      True      8.192315
# 277  None -0.589379        -0.589379  4.415595e-07      True      8.139273
#
# [278 rows x 6 columns]
# Sensor: 1.1inner-100watt
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -0.911715        -0.911715  2.748987e-07      True      8.057762
# 1    None -1.615049        -1.615049  1.421679e-07      True      8.516199
# 2    None -1.770107        -1.770106  1.271555e-07      True      8.180574
# 3    None -1.736844        -1.736844  1.305270e-07      True      8.218928
# 4    None -2.249421        -2.249421  9.373688e-08      True      8.216406
# ..    ...       ...              ...           ...       ...           ...
# 267  None -1.139935        -1.139935  2.139046e-07      True      8.080534
# 268  None -1.880029        -1.880029  1.183984e-07      True      8.166496
# 269  None -1.806319        -1.806319  1.243258e-07      True      7.785618
# 270  None -1.440460        -1.440459  1.629881e-07      True      7.995567
# 271  None -1.182199        -1.182199  2.051869e-07      True      7.716160
#
# [272 rows x 6 columns]
# Sensor: 1.1inner-200watt
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -1.664664        -1.664664  1.374489e-07      True      8.052034
# 1    None -1.429312        -1.429311  1.647136e-07      True      8.052798
# 2    None -2.104504        -2.104504  1.026821e-07      True      7.868735
# 3    None -1.764490        -1.764490  1.277696e-07      True      7.844067
# 4    None -1.664779        -1.664779  1.372461e-07      True      8.051393
# ..    ...       ...              ...           ...       ...           ...
# 269  None -1.355576        -1.355576  1.757216e-07      True      9.675367
# 270  None -1.737283        -1.737283  1.303608e-07      True      9.532123
# 271  None -1.602517        -1.602517  1.438510e-07      True      7.423252
# 272  None -1.745159        -1.745159  1.296349e-07      True      6.812691
# 273  None -1.137179        -1.137178  2.141923e-07      True      6.738668
#
# [274 rows x 6 columns]
# Sensor: 1.1outer-200watt
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -1.637159        -1.637158  1.399398e-07      True      6.816848
# 1    None -1.242360        -1.242360  1.936780e-07      True      6.829714
# 2    None -0.828990        -0.828990  3.050253e-07      True      6.769663
# 3    None -0.951225        -0.951225  2.623685e-07      True      7.134684
# 4    None -1.605957        -1.605956  1.436694e-07      True      7.006671
# ..    ...       ...              ...           ...       ...           ...
# 298  None -0.980981        -0.980981  2.531853e-07      True      7.901776
# 299  None -1.220043        -1.220043  1.982451e-07      True      7.789742
# 300  None -0.852466        -0.852466  2.957525e-07      True      7.775698
# 301  None -0.878116        -0.878116  2.860029e-07      True      7.698958
# 302  None -0.260463        -0.260463  1.034751e-06      True      8.100575
#
# [303 rows x 6 columns]
# Sensor: 1.1outer-100watt
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -0.998228        -0.998228  2.488945e-07      True      8.060502
# 1    None -1.055516        -1.055516  2.338785e-07      True      8.124889
# 2    None -0.547312        -0.547312  4.771149e-07      True      7.770773
# 3    None -0.753572        -0.753572  3.389554e-07      True      7.773813
# 4    None -1.372687        -1.372687  1.728452e-07      True      8.225537
# ..    ...       ...              ...           ...       ...           ...
# 266  None -1.338054        -1.338054  1.777039e-07      True      8.271771
# 267  None -1.163861        -1.163861  2.088847e-07      True      8.241096
# 268  None -0.193113        -0.193112  1.405399e-06      True      8.064369
# 269  None -0.995409        -0.995409  2.490179e-07      True      8.124336
# 270  None -1.032213        -1.032212  2.395685e-07      True      8.158634
#
# [271 rows x 6 columns]
# Sensor: 1.1inner-300watt
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -2.083078        -2.083078  1.036393e-07      True      7.902733
# 1    None -1.308436        -1.308435  1.827097e-07      True      8.181126
# 2    None -2.247521        -2.247521  9.406183e-08      True      8.196190
# 3    None -1.296173        -1.296173  1.843470e-07      True      8.156120
# 4    None -1.304389        -1.304389  1.832179e-07      True      8.169192
# ..    ...       ...              ...           ...       ...           ...
# 289  None -1.702922        -1.702922  1.336395e-07      True      7.633234
# 290  None -1.448531        -1.448531  1.621115e-07      True      7.641005
# 291  None -1.566552        -1.566552  1.480721e-07      True      7.937466
# 292  None -1.681812        -1.681812  1.358320e-07      True      7.619142
# 293  None -1.684988        -1.684987  1.350410e-07      True      7.987615
#
# [294 rows x 6 columns]
# Sensor: 0.9inner-300watt
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -1.969255        -1.969255  1.115177e-07      True      8.192213
# 1    None -1.461027        -1.461026  1.605107e-07      True      8.101022
# 2    None -1.178173        -1.178172  2.062036e-07      True      8.180878
# 3    None -1.420928        -1.420928  1.660079e-07      True      8.229508
# 4    None -1.371937        -1.371937  1.727485e-07      True      8.204467
# ..    ...       ...              ...           ...       ...           ...
# 259  None -1.877830        -1.877830  1.185087e-07      True      8.258419
# 260  None -1.422040        -1.422040  1.659997e-07      True      8.297682
# 261  None -1.633515        -1.633515  1.408712e-07      True      8.231302
# 262  None -1.897658        -1.897657  1.169233e-07      True      8.365416
# 263  None -1.282711        -1.282711  1.871101e-07      True      8.117159
#
# [264 rows x 6 columns]
# Sensor: 0.9outer-200watt
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -1.304730        -1.304730  1.835865e-07      True      8.342986
# 1    None -2.081441        -2.081441  1.040362e-07      True      8.289005
# 2    None -1.662024        -1.662023  1.379252e-07      True      8.245571
# 3    None -2.435607        -2.435607  8.470935e-08      True      8.408295
# 4    None -1.200363        -1.200363  2.022082e-07      True      8.296465
# ..    ...       ...              ...           ...       ...           ...
# 276  None -1.973391        -1.973391  1.110969e-07      True      8.162938
# 277  None -1.249433        -1.249433  1.925268e-07      True      8.212846
# 278  None -1.624925        -1.624924  1.413117e-07      True      8.153529
# 279  None -1.589446        -1.589445  1.451865e-07      True      7.911953
# 280  None -2.150310        -2.150310  9.958697e-08      True      8.226689
#
# [281 rows x 6 columns]
# Sensor: 0.9inner-100watt
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -1.553310        -1.553310  1.496134e-07      True      7.818405
# 1    None -1.709285        -1.709285  1.331175e-07      True      7.743890
# 2    None -2.004628        -2.004628  1.093515e-07      True      7.792371
# 3    None -1.562646        -1.562646  1.482838e-07      True      8.096694
# 4    None -1.818738        -1.818738  1.233661e-07      True      8.125411
# ..    ...       ...              ...           ...       ...           ...
# 299  None -1.600774        -1.600774  1.437693e-07      True      8.114638
# 300  None -1.210937        -1.210937  1.997081e-07      True      8.112997
# 301  None -1.452287        -1.452287  1.618181e-07      True      8.183148
# 302  None -1.458488        -1.458488  1.605527e-07      True      8.211415
# 303  None -1.581370        -1.581370  1.460082e-07      True      8.245418
#
# [304 rows x 6 columns]
# Sensor: 0.9outer-100watt
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -0.902042        -0.902042  2.776790e-07      True      7.902122
# 1    None -1.386221        -1.386221  1.705763e-07      True      8.317618
# 2    None -1.713719        -1.713719  1.325456e-07      True      8.262590
# 3    None -1.538722        -1.538722  1.508008e-07      True      8.391973
# 4    None -1.533593        -1.533593  1.515333e-07      True      8.082281
# ..    ...       ...              ...           ...       ...           ...
# 276  None -2.222962        -2.222962  9.554077e-08      True      7.790302
# 277  None -2.054033        -2.054032  1.057250e-07      True      7.759727
# 278  None -1.514345        -1.514345  1.539472e-07      True      7.777027
# 279  None -1.252024        -1.252024  1.921398e-07      True      7.810333
# 280  None -1.852147        -1.852147  1.204986e-07      True      7.693393
#
# [281 rows x 6 columns]
# Sensor: 0.9inner-200watt
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -1.618416        -1.618415  1.423925e-07      True      7.638013
# 1    None -0.999887        -0.999887  2.486442e-07      True      7.566212
# 2    None -1.327198        -1.327198  1.799131e-07      True      7.728773
# 3    None -1.578203        -1.578203  1.467527e-07      True      7.654730
# 4    None -1.308303        -1.308303  1.822777e-07      True      7.990038
# ..    ...       ...              ...           ...       ...           ...
# 269  None -0.639511        -0.639511  4.038689e-07      True      7.823074
# 270  None -1.592967        -1.592967  1.447526e-07      True      7.973428
# 271  None -1.399701        -1.399701  1.687678e-07      True      8.050554
# 272  None -1.722622        -1.722621  1.316542e-07      True      8.265707
# 273  None -1.303097        -1.303097  1.834903e-07      True      8.233301
#
# [274 rows x 6 columns]
# Sensor: 0.9outer-300watt
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -1.223616        -1.223616  1.974430e-07      True      8.157456
# 1    None -1.599269        -1.599268  1.442193e-07      True      8.155297
# 2    None -1.511613        -1.511613  1.543414e-07      True      8.174297
# 3    None -1.668615        -1.668615  1.367992e-07      True      8.186537
# 4    None -0.878612        -0.878612  2.864176e-07      True      8.262606
# ..    ...       ...              ...           ...       ...           ...
# 240  None -1.908686        -1.908686  1.162215e-07      True      8.350340
# 241  None -1.104590        -1.104590  2.214488e-07      True      8.316530
# 242  None -1.614674        -1.614674  1.422486e-07      True      8.434783
# 243  None -1.129232        -1.129231  2.162892e-07      True      8.401338
# 244  None -0.602038        -0.602037  4.307412e-07      True      8.307001
#
# [245 rows x 6 columns]
# Sensor: 1.3outer-100watt
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -1.561322        -1.561322  1.482244e-07      True      8.226847
# 1    None -1.949166        -1.949166  1.129482e-07      True      8.284389
# 2    None -1.482088        -1.482087  1.576446e-07      True      8.440342
# 3    None -1.394316        -1.394316  1.696230e-07      True      8.409263
# 4    None -1.397331        -1.397331  1.692095e-07      True      8.445887
# ..    ...       ...              ...           ...       ...           ...
# 260  None -1.303059        -1.303058  1.833006e-07      True      7.993849
# 261  None -1.012216        -1.012216  2.450550e-07      True      8.222151
# 262  None -1.483192        -1.483192  1.575423e-07      True      7.999221
# 263  None -1.075072        -1.075072  2.288865e-07      True      8.007181
# 264  None -1.754755        -1.754755  1.286011e-07      True      7.975663
#
# [265 rows x 6 columns]
# Sensor: 1.3outer-300watt
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -0.579920        -0.579920  4.472873e-07      True      7.925241
# 1    None -1.159895        -1.159895  2.094739e-07      True      8.720140
# 2    None -0.607054        -0.607054  4.265678e-07      True      8.232181
# 3    None -0.903784        -0.903784  2.771577e-07      True      7.610056
# 4    None -0.344834        -0.344833  7.737391e-07      True      7.793399
# ..    ...       ...              ...           ...       ...           ...
# 250  None -0.948780        -0.948780  2.623098e-07      True      8.327197
# 251  None -0.616989        -0.616989  4.195865e-07      True      7.837333
# 252  None -0.205198        -0.205198  1.322857e-06      True      8.209062
# 253  None -0.459432        -0.459432  5.734156e-07      True      8.152466
# 254  None -0.555381        -0.555381  4.694508e-07      True      7.857605
#
# [255 rows x 6 columns]
# Sensor: 1.3inner-300watt
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -2.935588        -2.935588  6.535469e-08      True      8.181972
# 1    None -2.671679        -2.671679  7.468020e-08      True      7.788448
# 2    None -2.125854        -2.125854  1.012789e-07      True      8.119125
# 3    None -0.914003        -0.914003  2.736519e-07      True      7.954143
# 4    None -1.277644        -1.277644  1.874735e-07      True      8.210735
# ..    ...       ...              ...           ...       ...           ...
# 250  None -1.379878        -1.379878  1.718516e-07      True      8.261262
# 251  None -1.175071        -1.175071  2.069227e-07      True      8.034994
# 252  None -1.328766        -1.328766  1.795184e-07      True      8.036254
# 253  None -1.356015        -1.356015  1.754674e-07      True      8.076549
# 254  None -1.210231        -1.210230  1.996450e-07      True      8.171634
#
# [255 rows x 6 columns]
# Sensor: 1.3inner-200watt
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -0.961327        -0.961327  2.586369e-07      True      7.902887
# 1    None -1.950801        -1.950801  1.129985e-07      True      8.102988
# 2    None -1.912319        -1.912319  1.156985e-07      True      8.044495
# 3    None -1.805853        -1.805853  1.243886e-07      True      7.870663
# 4    None -1.317584        -1.317584  1.809451e-07      True      7.831832
# ..    ...       ...              ...           ...       ...           ...
# 261  None -2.017830        -2.017829  1.081506e-07      True      8.369056
# 262  None -1.893246        -1.893246  1.173676e-07      True      8.273085
# 263  None -1.433445        -1.433445  1.643612e-07      True      8.377892
# 264  None -1.309787        -1.309787  1.825952e-07      True      8.116423
# 265  None -1.096816        -1.096816  2.233171e-07      True      8.305868
#
# [266 rows x 6 columns]
# Sensor: 1.3inner-100watt
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -1.361180        -1.361180  1.741437e-07      True      7.909381
# 1    None -1.717224        -1.717223  1.318945e-07      True      8.439522
# 2    None -1.177968        -1.177968  2.059993e-07      True      8.333801
# 3    None -1.134868        -1.134867  2.145895e-07      True      8.467728
# 4    None -0.848635        -0.848635  2.966366e-07      True      8.368475
# ..    ...       ...              ...           ...       ...           ...
# 281  None -1.358274        -1.358274  1.749944e-07      True      8.032887
# 282  None -1.283061        -1.283061  1.866388e-07      True      8.089761
# 283  None -1.526551        -1.526550  1.525693e-07      True      7.886292
# 284  None -1.228459        -1.228459  1.963403e-07      True      8.144662
# 285  None -1.304691        -1.304691  1.833791e-07      True      7.842639
#
# [286 rows x 6 columns]
# Sensor: 1.3outer-200watt
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -1.823726        -1.823725  1.229292e-07      True      8.024296
# 1    None -1.612184        -1.612184  1.428226e-07      True      8.058661
# 2    None -1.151487        -1.151487  2.117109e-07      True      7.690542
# 3    None -2.013123        -2.013123  1.084774e-07      True      7.889511
# 4    None -1.507396        -1.507396  1.549153e-07      True      8.152801
# ..    ...       ...              ...           ...       ...           ...
# 273  None -1.538191        -1.538190  1.511429e-07      True      8.096059
# 274  None -1.342017        -1.342016  1.772407e-07      True      8.037006
# 275  None -1.441906        -1.441906  1.634132e-07      True      8.102665
# 276  None -1.251993        -1.251993  1.925378e-07      True      8.194980
# 277  None -1.502895        -1.502895  1.551357e-07      True      8.251351
#
# [278 rows x 6 columns]
# Sensor: 0.7outer-100watt-lB5LIS
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None -1.236883        -1.236882  1.948706e-07      True      8.270036
# 1    None -0.986566        -0.986566  2.518578e-07      True      8.305826
# 2    None -1.230500        -1.230500  1.957547e-07      True      8.178557
# 3    None -0.655439        -0.655439  3.936947e-07      True      7.724196
# 4    None -0.394200        -0.394199  6.733521e-07      True      7.893046
# ..    ...       ...              ...           ...       ...           ...
# 255  None -0.290168        -0.290168  9.247591e-07      True      8.265484
# 256  None -0.740708        -0.740708  3.442513e-07      True      7.997102
# 257  None -0.235585        -0.235584  1.146696e-06      True      8.303668
# 258  None -0.665913        -0.665913  3.870712e-07      True      8.388517
# 259  None -0.536314        -0.536314  4.876267e-07      True      8.368294
#
# [260 rows x 6 columns]
# Sensor: 0.7outer-200watt-0Pp0qm
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None  0.091011         0.091011 -3.065297e-06      True      8.245414
# 1    None -0.007813        -0.007812  3.541149e-05      True      8.128490
# 2    None -0.285639        -0.285638  9.382146e-07      True      8.415047
# 3    None -0.840647        -0.840646  2.997006e-07      True      8.073077
# 4    None -0.722762        -0.722762  3.541460e-07      True      8.171834
# ..    ...       ...              ...           ...       ...           ...
# 255  None -0.987888        -0.987888  2.513345e-07      True      8.329547
# 256  None  0.218293         0.218293 -1.297079e-06      True      8.063381
# 257  None  0.505888         0.505889 -5.766701e-07      True      8.135775
# 258  None  0.404600         0.404600 -7.133597e-07      True      8.979121
# 259  None  0.076855         0.076856 -3.621258e-06      True      9.803878
#
# [260 rows x 6 columns]
# Sensor: 0.7inner-300watt-Zo8w7U
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None  2.766693         2.766693 -1.290314e-07      True      9.514809
# 1    None  2.299900         2.299901 -1.488168e-07      True      8.389527
# 2    None  3.363498         3.363498 -1.112991e-07      True      6.680478
# 3    None  2.715389         2.715390 -1.308699e-07      True      6.681872
# 4    None  2.637007         2.637008 -1.338716e-07      True      6.711999
# ..    ...       ...              ...           ...       ...           ...
# 222  None  3.375294         3.375294 -1.110562e-07      True      7.636916
# 223  None  3.837836         3.837836 -1.010962e-07      True      7.596705
# 224  None  3.331441         3.331442 -1.122200e-07      True      7.667904
# 225  None  2.542415         2.542415 -1.376620e-07      True      7.694636
# 226  None  3.424367         3.424367 -1.098218e-07      True      7.568782
#
# [227 rows x 6 columns]
# Sensor: 0.7outer-300watt-PzsIeS
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None  0.284963         0.284963 -1.001532e-06      True      7.594980
# 1    None -0.086786        -0.086785  3.162848e-06      True      7.662628
# 2    None  0.165379         0.165380 -1.702407e-06      True      7.403575
# 3    None  0.183572         0.183572 -1.533910e-06      True      7.700596
# 4    None  0.096847         0.096847 -2.887801e-06      True      7.445372
# ..    ...       ...              ...           ...       ...           ...
# 127  None  0.385909         0.385909 -7.478617e-07      True      7.721041
# 128  None -0.318983        -0.318983  8.388512e-07      True      7.829414
# 129  None -0.027640        -0.027639  9.999064e-06      True      8.055717
# 130  None -0.118115        -0.118115  2.313334e-06      True      8.261047
# 131  None -0.264012        -0.264012  1.018210e-06      True      7.678467
#
# [132 rows x 6 columns]
# Sensor: 0.7inner-200watt-jolm8U
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None  1.508502         1.508502 -2.126403e-07      True      7.802620
# 1    None  2.059335         2.059335 -1.637571e-07      True      7.978539
# 2    None  1.972966         1.972967 -1.691726e-07      True      8.030052
# 3    None  1.539637         1.539637 -2.084605e-07      True      8.092694
# 4    None  2.597390         2.597390 -1.354127e-07      True      7.666847
# ..    ...       ...              ...           ...       ...           ...
# 245  None  2.156601         2.156602 -1.573067e-07      True      7.778198
# 246  None  0.852045         0.852045 -3.533870e-07      True      8.186094
# 247  None  1.009217         1.009217 -3.027092e-07      True      7.639378
# 248  None  1.253955         1.253955 -2.494873e-07      True      8.047651
# 249  None  0.740551         0.740551 -4.020578e-07      True      7.726071
#
# [250 rows x 6 columns]
# Sensor: 0.7inner-100watt-67V2Iv
#        ID  Expected  Predicted (enc)       % Error  Correct?  Time enc (s)
# 0    None  2.580497         2.580497 -1.362374e-07      True      7.727816
# 1    None  2.284752         2.284752 -1.500047e-07      True      7.947972
# 2    None  2.434051         2.434051 -1.427937e-07      True      8.053971
# 3    None  2.813488         2.813488 -1.272224e-07      True      7.989590
# 4    None  1.820065         1.820065 -1.808259e-07      True      8.209704
# ..    ...       ...              ...           ...       ...           ...
# 281  None  3.152521         3.152521 -1.167043e-07      True      7.774275
# 282  None  2.429952         2.429953 -1.423857e-07      True      8.320367
# 283  None  2.389227         2.389227 -1.448382e-07      True      8.008401
# 284  None  2.480647         2.480647 -1.401752e-07      True      8.240703
# 285  None  2.772343         2.772343 -1.287156e-07      True      7.744057
#
# [286 rows x 6 columns]
